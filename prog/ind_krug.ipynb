# %% [markdown]
# ### Экипаж экскаватора работал  360 мин. Из них основная работа заняла 230 мин, вспомогательная работа – 90 мин, простой по техническим причинам – 20 мин и подготовительные работы – 20 мин. Постройте круговую диаграмму распределения рабочего времени этого экипажа.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %%
vals = [230, 90, 20, 20]

labels = ["Основная работа", "Вспомогательная работа", "Простой по тех. причинам", "Подготовительные работы"]

fig, ax = plt.subplots()

ax.pie(vals, labels=labels, autopct='%1.1f%%', explode=explode,
wedgeprops={'lw':1, 'ls':''})

ax.axis("equal")
plt.show()
